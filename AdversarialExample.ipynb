# %% [markdown]
# <a href="https://colab.research.google.com/github/poi90/AdversarialExampleGenerating/blob/master/AdversarialExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd adversarial-yolo-master/
# Out:
# /content/drive/My Drive/AdverPatch/adversarial-yolo-master

# %%
rm -r AdPatch/

# %%
# !zip adversarial-yolo-master.zip -r adversarial-yolo-master/
# Out:
#   adding: adversarial-yolo-master/ (stored 0%)
#   adding: adversarial-yolo-master/README.md (deflated 45%)
#   adding: adversarial-yolo-master/persons/ (stored 0%)
#   adding: adversarial-yolo-master/persons/person_066.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_024.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_062.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_030.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_073.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_032.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_056.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_015.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_018.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_070.jpg (deflated 0%)
#   adding: adversarial-yolo-master/persons/person_031.jpg (deflated 0%)
# ...

# %%
# !git remote add origin git@github.com:poi90/AdversarialPatch.git

# %%
# !pip install tensorboardX tensorboard
# Out:
# ...
#      |████████████████████████████████| 317kB 4.9MB/s
# ...

# %%
cd drive/My\ Drive/AdverPatch

# %%
# !python train_patch.py paper_obj
# Out:
# starting test read
# img read!
# ...
# convolution havn't activate linear
# convolution havn't activate linear
# convolution havn't activate linear
# 80
# One epoch is 250
# Running epoch 0:   0% 0/250 [00:00<?, ?it/s]2020-08-07 23:20:10.797050: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# train_patch.py:88: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   with autograd.detect_anomaly():
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3447: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# ...

# %%
# !python eval.py
# Out:
#  69% 691/1000 [00:27<00:10, 29.64it/s]

# %%
import torch
print(torch.__version__())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-61ccac19e331> in <module>()
#       1 import torch
# ----> 2 print(torch.__version__())
#
# TypeError: 'str' object is not callable

# %%
# !zip -r eval_code.zip eval_code/*
# Out:
# zip error: Interrupted (aborting)

# %%
pip install torch==1.5.0+cu101 torchvision==0.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 703.8MB 17kB/s
# ...
#      |████████████████████████████████| 6.6MB 27.4MB/s
# ...
#   Found existing installation: torch 1.6.0+cu101
#     Uninstalling torch-1.6.0+cu101:
#       Successfully uninstalled torch-1.6.0+cu101
#   Found existing installation: torchvision 0.7.0+cu101
#     Uninstalling torchvision-0.7.0+cu101:
#       Successfully uninstalled torchvision-0.7.0+cu101
# ...

# %%
pip install tensorboardX tensorboard
# Out:
# ...
#      |████████████████████████████████| 317kB 7.2MB/s
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
